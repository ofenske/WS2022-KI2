# %% [markdown]
# # Entscheidungsbäume
#
# Alice beobachtet die Tennisspieler auf dem Tennisplatz vor ihrem Haus. Sie möchte herausfinden, wie die Spieler entscheiden, wann sie Tennis spielen und wann sie nicht spielen. Sie hat die folgenden Beobachtungen gemacht:
#
# ![grafik.png](attachment:grafik.png)
#
# Aufgabe ist es nun einen Entscheidungsbaum aus den Trainingsdaten zu lernen. Dabei soll die Informationsentropie als Maß für die Knotenverunreinigung dienen.

# %% [markdown]
# 1. Aufgabe ist es nun einen Entscheidungsbaum aus den Trainingsdaten zu lernen. Welche Metriken haben sie in der Vorlesung kennengerlernt, die als Split-Kritrium dienen können? Was sagt welche Metrik aus?

# %% [markdown]
# Lösung:

# %% [markdown]
# 2. Berechnen Sie die Entropie des Wurzelknotens eines Entscheidungsbaumes für das oben gegebene Beispiel!

# %% [markdown]
# Lösung:

# %% [markdown]
# 3. Berechnen Sie das Reinheitsmaß für einen Split auf $Outlook$ = $Overcast$.

# %% [markdown]
# Lösung:

# %% [markdown]
# Insgesamt ergeben sich für den Reinheitsgewinn aller Attribute bzgl. des ersten Splits folgende Werte:
# ![Bildschirm­foto 2023-01-24 um 15.44.59.png](attachment:03b1c8d9-53fb-4697-b4b2-9f2317212d0c.png)

# %% [markdown]
# Dasselbe Vorgehen wiederholt sich dann für jeden möglichen Split im dadurch entstehenden Entscheidungsbaum:
#
# ![Bildschirm­foto 2023-01-24 um 15.39.48.png](attachment:09a75c5e-65af-4136-b49e-6916f24c8136.png)

# %% [markdown]
# # Entscheidungsbäume in Python
# Laden Sie sich den Datensatz aus "iris.csv" als Pandas-Datenframe.
# Trainieren Sie einen Entscheidungsbaum auf dem Datensatz, und verwenden Sie 2/3 der Daten zum Trainieren und 1/3 zum Testen.

# %%
import numpy as np
from sklearn import tree
from sklearn import model_selection
import pandas as pd

dat = 'Implement me!'

# converting data from Name column to strings
dat["Name"] = np.array([str(xi) for xi in dat["Name"]])

# split dataframe into train and test data
train,test = 'Implement me!'

x_train = 'Implement me!'
x_test =  'Implement me!'

y_train = 'Implement me!'
y_test =  'Implement me!'

# intialize DT classifier
clf = 'Implement me!'

# train clf
'Implement me!'

# compute predictions with our trained classifier
y_pred = 'Implement me!'

# %% [markdown]
# # Evaluation
# Ein typisches Maß zur Bewertung der Leistung eines Klassifikators ist die Konfusionsmatrix. Für jede Klasse zeigt diese Matrix die vorhergesagte Klasse für jede Probe mit dieser Klasse.
# ![Bildschirm­foto 2023-01-24 um 15.57.15.png](attachment:077fbbfd-c4f5-418e-8d3a-6a57fbad1d70.png)

# %% [markdown]
# 1. Informieren sie sich im Internet darüber, wie sie mithilfe von Scikit-learn die Konfusionsmatrix berechnen können! Implementieren sie eine Funktion, welche gegeben die Vorhersagen ihres DTs und die wahren Label der einzelnen Datenpunkte die Konfusionsmatrix berechnet und ausgibt!

# %%
# maybe you have to import something?

def get_cm(y_test, y_pred):
    print('Implement me!')
    
get_cm(y_test, y_pred)

# %% [markdown]
# 2. Informieren sie sich im Internet darüber, wie sie mithilfe von Scikit-learn die Metriken Accuracy, Precisision Recall und F1-Score berechnen können. Implementieren sie auch hier wieder eine Funktion, welche Ihnen diese Metriken für einen trainierten Klassifikator berechnet und ausgibt!

# %%
# maybe you have to import something?

def get_cr(y_test, y_pred):
    print('Implement me!')
get_cr(y_test, y_pred)
